# %%
dbutils.notebook.run("/Workspace/Users/kazuto2548@gmail.com/Flight Project/Bronze FW", 0 ,{"pipeline_name" : "flight_pipeline"})

# %%
dbutils.notebook.run("/Workspace/Users/kazuto2548@gmail.com/Flight Project/Silver FW", 0 ,{"pipeline_name" : "flight_pipeline"})
