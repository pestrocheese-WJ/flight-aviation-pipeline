# %%
from pyspark.sql.functions import *

# %%
# %run ./Framework

# %%
dbutils.widgets.text("pipeline_name", "")
pipeline_name = dbutils.widgets.get("pipeline_name")

# %%
bronze_job = Bronze.from_conf(pipeline_name)
bronze_df = bronze_job.read()

# %%
bronze_job.load_to_bronze_table(bronze_df)
